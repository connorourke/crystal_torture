# %%
import matplotlib.pyplot as plt
import random as rand

# %%
def plot_circle(axis,x,y,colour):
    circle = plt.Circle((x, y), 0.2, color=colour)
    ax.add_artist(circle)

# %%
fig, ax = plt.subplots(figsize = (5, 5))
ax.set_xlim(left=0, right=10, emit=True, auto=False)
ax.set_ylim(bottom=0, top=10, emit=True, auto=False)
plt.axis('off')


#plot_circle(ax,1,1,'blue')
#plot_circle(ax,0.5,0.5,'green')

for x in range(1,10):
    for y in range(1,10):
        random_no = rand.random()
        if ra
        print(random_no)  
        plot_circle(ax,x,y,'blue')
        plot_circle(ax,x+0.5,y+0.5,'green')
# Out:
# 0.614197632108
# 0.167528224945
# 0.405957549754
# 0.27235127824
# 0.251395779635
# 0.467096451351
# 0.71088517041
# 0.755559559994
# 0.311661778248
# 0.130721259789
# 0.276768045073
# 0.0877468699214
# 0.256264478331
# 0.209804427512
# 0.88342502122
# 0.721789926758
# 0.430806231872
# 0.262221578357
# 0.703849769976
# 0.944911875117
# 0.579120078977
# 0.280419168239
# 0.674684839799
# 0.335393537282
# 0.145775370535
# 0.7641877283
# 0.286233719562
# 0.723013169045
# 0.346716912805
# 0.625186798472
# 0.685531459917
# 0.920486835736
# 0.602051391192
# 0.0412531555973
# 0.737879220617
# 0.803921896011
# 0.859414907003
# 0.132131394832
# 0.335934790176
# 0.365864496294
# 0.939431077119
# 0.931804239181
# 0.536900000701
# 0.202469090317
# 0.988221865288
# 0.149154498494
# 0.447473071507
# 0.148593273122
# 0.764745103987
# 0.301762768974
# 0.821803908381
# 0.355056337216
# 0.47170375678
# 0.665955293912
# 0.159289245549
# 0.828527035655
# 0.941020264205
# 0.781944057559
# 0.741775893738
# ...
